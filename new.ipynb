# %%
# this is created to be added to my first github repository
class HelloWorld: 
    def__init__(self, name):
        self.name = name
    import time
    def greet(self):
        print(f"Hello, {self.name}!")
